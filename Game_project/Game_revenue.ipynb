# %%
# Import Dependencies
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# Load the file
gaming_file_to_load = "Resources/vgsales.csv"

# Read the file
gaming_file_df = pd.read_csv(gaming_file_to_load, encoding="ISO-8859-1")
gaming_file_df
data = gaming_file_df.head()
data
gaming_file_df['Platform'].nunique()

# Compare how each platform is doing in each country
# Visisualize revenue per country - Jasmine
# Calculate total sales per country
group_data = gaming_file_df.groupby(['Platform'])[['NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']].sum().reset_index()
#df1.groupby(["City"])[['Name']].count()
#type(group_data)
group_data
ax = group_data[['NA_Sales', 'EU_Sales','JP_Sales','Other_Sales','Global_Sales']].plot(kind='bar', title ="Total Revenue Per Region", figsize=(15, 10), legend=True, fontsize=12)
#ax.set_xlabel(group_data["Platform"], fontsize=12)
ax.set_xticklabels(group_data.Platform)
ax.set_ylabel("Total Revenue (Dollars)", fontsize=12)
plt.show()

# %%
# Create a reference the CSV file desired
csv_path = "Resources/vgsales.csv"

# Read the CSV into a Pandas DataFrame
game_sales = pd.read_csv(csv_path)

# Print the first five rows of data to the screen
game_sales.head(10)
# Out:
#    Rank                       Name Platform    Year         Genre Publisher  \
# 0     1                 Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2          Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3             Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4          Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5   Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
# 5     6                     Tetris       GB  1989.0        Puzzle  Nintendo
# 6     7      New Super Mario Bros.       DS  2006.0      Platform  Nintendo
# 7     8                   Wii Play      Wii  2006.0          Misc  Nintendo
# 8     9  New Super Mario Bros. Wii      Wii  2009.0      Platform  Nintendo
# 9    10                  Duck Hunt      NES  1984.0       Shooter  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37
# 5     23.20      2.26      4.22         0.58         30.26
# 6     11.38      9.23      6.50         2.90         30.01
# 7     14.03      9.20      2.93         2.85         29.02
# 8     14.59      7.06      4.70         2.26         28.62
# 9     26.93      0.63      0.28         0.47         28.31

# %%
# Total sale per platform 
platform_sum = game_sales.groupby(['Platform']).sum()
platform_sum


#Global sale per platform
Global = platform_sum['Global_Sales']
Global
g_df = pd.DataFrame(Global).copy()
g_df
# Out:
#           Global_Sales
# Platform
# 2600             97.08
# 3DO               0.10
# 3DS             247.46
# DC               15.97
# DS              822.49
# GB              255.45
# GBA             318.50
# GC              199.36
# GEN              28.36
# GG                0.04
# N64             218.88
# NES             251.07
# NG                1.44
# PC              258.82
# PCFX              0.03
# PS              730.66
# PS2            1255.64
# PS3             957.84
# PS4             278.10
# PSP             296.28
# PSV              61.93
# SAT              33.59
# SCD               1.87
# SNES            200.05
# TG16              0.16
# WS                1.42
# Wii             926.71
# WiiU             81.86
# X360            979.96
# XB              258.26
# XOne            141.06

# %%
#Total unit sales per platform
g_df['Total Units Per Platform'] = game_sales['Platform'].value_counts()
g_df
#Average Gross revenue per platform
g_df['Avg'] = g_df['Global_Sales']/g_df['Total Units Per Platform']
g_df
g_df.style.format({
    'Avg': '{:,.2f}'.format
})

g_df['Avg'] = g_df['Avg'].mul(100).astype(int).astype(str)
g_df
#df.style.format({
#    'A': '{:,.1f}'.format,
#    'B': '{:,.3f}'.format,
#})
# Out:
#           Global_Sales  Total Units Per Platform  Avg
# Platform
# 2600             97.08                       133   72
# 3DO               0.10                         3    3
# 3DS             247.46                       509   48
# DC               15.97                        52   30
# DS              822.49                      2163   38
# GB              255.45                        98  260
# GBA             318.50                       822   38
# GC              199.36                       556   35
# GEN              28.36                        27  105
# GG                0.04                         1    4
# N64             218.88                       319   68
# NES             251.07                        98  256
# NG                1.44                        12   12
# PC              258.82                       960   26
# PCFX              0.03                         1    3
# PS              730.66                      1196   61
# PS2            1255.64                      2161   58
# PS3             957.84                      1329   72
# PS4             278.10                       336   82
# PSP             296.28                      1213   24
# PSV              61.93                       413   14
# SAT              33.59                       173   19
# SCD               1.87                         6   31
# SNES            200.05                       239   83
# TG16              0.16                         2    8
# WS                1.42                         6   23
# Wii             926.71                      1325   69
# WiiU             81.86                       143   57
# X360            979.96                      1265   77
# XB              258.26                       824   31
# XOne            141.06                       213   66

# %%
g_df['Sum of All Global Sales'] = g_df['Global_Sales'].sum()
g_df
# Out:
#           Global_Sales  Total Units Per Platform  Avg  Sum of All Global Sales
# Platform
# 2600             97.08                       133   72                  8920.44
# 3DO               0.10                         3    3                  8920.44
# 3DS             247.46                       509   48                  8920.44
# DC               15.97                        52   30                  8920.44
# DS              822.49                      2163   38                  8920.44
# GB              255.45                        98  260                  8920.44
# GBA             318.50                       822   38                  8920.44
# GC              199.36                       556   35                  8920.44
# GEN              28.36                        27  105                  8920.44
# GG                0.04                         1    4                  8920.44
# N64             218.88                       319   68                  8920.44
# NES             251.07                        98  256                  8920.44
# NG                1.44                        12   12                  8920.44
# PC              258.82                       960   26                  8920.44
# PCFX              0.03                         1    3                  8920.44
# PS              730.66                      1196   61                  8920.44
# PS2            1255.64                      2161   58                  8920.44
# PS3             957.84                      1329   72                  8920.44
# PS4             278.10                       336   82                  8920.44
# PSP             296.28                      1213   24                  8920.44
# PSV              61.93                       413   14                  8920.44
# SAT              33.59                       173   19                  8920.44
# SCD               1.87                         6   31                  8920.44
# SNES            200.05                       239   83                  8920.44
# TG16              0.16                         2    8                  8920.44
# WS                1.42                         6   23                  8920.44
# Wii             926.71                      1325   69                  8920.44
# WiiU             81.86                       143   57                  8920.44
# X360            979.96                      1265   77                  8920.44
# XB              258.26                       824   31                  8920.44
# XOne            141.06                       213   66                  8920.44

# %%
#percent of total sales globaly
g_df['Percent of Total Sales Globaly'] = g_df['Global_Sales']/g_df['Sum of All Global Sales']
g_df['Percent of Total Sales Globaly'] = g_df['Percent of Total Sales Globaly'].mul(100)
#.astype(int)

g_df.head()
# Out:
#           Global_Sales  Total Units Per Platform Avg  Sum of All Global Sales  \
# Platform
# 2600             97.08                       133  72                  8920.44
# 3DO               0.10                         3   3                  8920.44
# 3DS             247.46                       509  48                  8920.44
# DC               15.97                        52  30                  8920.44
# DS              822.49                      2163  38                  8920.44
#
#           Percent of Total Sales Globaly
# Platform
# 2600                            1.088287
# 3DO                             0.001121
# 3DS                             2.774078
# DC                              0.179027
# DS                              9.220285

# %%
g_df = g_df.reset_index()
#g_df.rename_axis(None, axis=1)
print(g_df.columns)
g_df['Avg']=g_df['Avg'].astype(float)
g_df['Avg'].dtype
# Out:
# Index(['Platform', 'Global_Sales', 'Total Units Per Platform', 'Avg',
#        'Sum of All Global Sales', 'Percent of Total Sales Globaly'],
#       dtype='object')
# dtype('float64')

# %%
g_df.head()
# Out:
#   Platform  Global_Sales  Total Units Per Platform   Avg  \
# 0     2600         97.08                       133  72.0
# 1      3DO          0.10                         3   3.0
# 2      3DS        247.46                       509  48.0
# 3       DC         15.97                        52  30.0
# 4       DS        822.49                      2163  38.0
#
#    Sum of All Global Sales  Percent of Total Sales Globaly
# 0                  8920.44                        1.088287
# 1                  8920.44                        0.001121
# 2                  8920.44                        2.774078
# 3                  8920.44                        0.179027
# 4                  8920.44                        9.220285

# %%
#create bar graph
ax = g_df[['Platform', 'Avg']].plot(kind ='bar', title ="Average Sale Per Platform", figsize=(15, 10), legend=True, fontsize=12)  
#ax.set_xlabel(g_df["Platform"], fontsize=12)
ax.set_xticklabels(g_df.Platform)
ax.set_ylabel("Avg", fontsize=12)
plt.show()

# %%
path = "Resources/vgsales.csv"
data = pd.read_csv(path)
df = pd.DataFrame(data)


#drop columns
columns_na = ['Rank', 'Platform', 'Year', 'Genre', 'Publisher','EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
columns_eu = ['Rank', 'Platform', 'Year', 'Genre', 'Publisher','NA_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales']
columns_jp = ['Rank', 'Platform', 'Year', 'Genre', 'Publisher','NA_Sales', 'EU_Sales', 'Other_Sales', 'Global_Sales']
columns_other = ['Rank', 'Platform', 'Year', 'Genre', 'Publisher','NA_Sales', 'EU_Sales', 'JP_Sales', 'Global_Sales']
columns_global = ['Rank', 'Platform', 'Year', 'Genre', 'Publisher','NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']
na_sales = df.drop(columns_na, 1)
eu_sales = df.drop(columns_eu, 1)
jp_sales = df.drop(columns_jp, 1)
other_sales = df.drop(columns_other, 1)
global_sales = df.drop(columns_global, 1)


# sort the dataframe by ascending value of sales per country
na_sales_sorted = na_sales.sort_values(by="NA_Sales", ascending=0)
eu_sales_sorted = eu_sales.sort_values(by="EU_Sales", ascending=0)
jp_sales_sorted = jp_sales.sort_values(by="JP_Sales", ascending=0) 
other_sales_sorted = other_sales.sort_values(by="Other_Sales", ascending=0)
global_sales_sorted = global_sales.sort_values(by="Global_Sales", ascending=0)


#pick top 10 for each region
top_na = na_sales_sorted[:10]
top_eu = eu_sales_sorted[:10]
top_jp = jp_sales_sorted[:10]
top_other = other_sales_sorted[:10]
top_global = global_sales_sorted[:10]

#charts
na_chart = top_na.plot(kind = 'bar')
na_chart.set_xlabel("Top_10")
na_chart.set_ylabel("Sales")
plt.show()
plt.tight_layout()

eu_chart = top_eu.plot(kind = 'bar')
eu_chart.set_xlabel("Top_10")
eu_chart.set_ylabel("Sales")
plt.show()
plt.tight_layout()

jp_chart = top_jp.plot(kind = 'bar')
jp_chart.set_xlabel("Top_10")
jp_chart.set_ylabel("Sales")
plt.show()
plt.tight_layout()

global_chart = top_global.plot(kind = 'bar')
global_chart.set_xlabel("Top_10")
global_chart.set_ylabel("Sales")
plt.show()
plt.tight_layout()

closer = pd.DataFrame(top_global)
closer
# Out:
#                         Name  Global_Sales
# 0                 Wii Sports         82.74
# 1          Super Mario Bros.         40.24
# 2             Mario Kart Wii         35.82
# 3          Wii Sports Resort         33.00
# 4   Pokemon Red/Pokemon Blue         31.37
# 5                     Tetris         30.26
# 6      New Super Mario Bros.         30.01
# 7                   Wii Play         29.02
# 8  New Super Mario Bros. Wii         28.62
# 9                  Duck Hunt         28.31
